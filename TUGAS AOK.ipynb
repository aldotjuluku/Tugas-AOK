# %% [markdown]
# <h1 align = "center"> <font color='red'> TUGAS ARSITEKTUR DAN ORGANISASI KOMPUTER </h1> </font>
# <h2 align = "center"> <font color='black'> REIVALDO TJULUKU NIM.19101106044</h2> </font>
# <strong><h3 align = "center"> <font color='yellow'> KELOMPOK 8 </h3> </font></strong>

# %% [markdown]
# ## **STORAGE**

# %%
from IPython.display import Image
Image(filename="memori1.jpg", width=400, height=400)

# %%
from IPython.display import Image
Image(filename="cloudstorage.jpg", width=400, height=400)

# %% [markdown]
# Storage unit merupakan tempat untuk menyimpan atau menampung data  program dalam suatu sistem
#
# Storage unit secara umum diklasifikasikan kedalam beberapa jenis yaitu :

# %% [markdown]
# <h2 align = "left"> <font color='green'> 1.Internal Storage </h2> </font>

# %%
print ("Internal Storage atau sering disebut juga sebagai Main Storage adalah memori yang memiliki tugas atau fungsi sebagai penampung data dan instruksi / progaram dari input device untuk dilanjutkan ke CPU (Central Processing Unit) dan juga tempat untuk menampung data / hasil kerja dari CPU sebelum dilanjutkan ke Output Unit.")
print ("Program dan hasil pengolahan yang terdapat dalam internal storage ini hanya bersifat sementara waktu selama pengolahan berlangsung.")
# Out:
# Internal Storage atau sering disebut juga sebagai Main Storage adalah memori yang memiliki tugas atau fungsi sebagai penampung data dan instruksi / progaram dari input device untuk dilanjutkan ke CPU (Central Processing Unit) dan juga tempat untuk menampung data / hasil kerja dari CPU sebelum dilanjutkan ke Output Unit.
# Program dan hasil pengolahan yang terdapat dalam internal storage ini hanya bersifat sementara waktu selama pengolahan berlangsung.

# %% [markdown]
# > Semakin berat aplikasi yang akan dijalankan, maka bobot RAM akan semakin besar.

# %% [markdown]
# * <h3><font color='orange'>RAM</h2></font>

# %%
Image(url="data:image/jpeg;base64,...")
# Out:
# <img src="data:image/jpeg;base64,..."/>

# %%
print ("RAM yang merupakan singkatan dari Random Access Memory adalah sebuah perangkat keras komputer yang berfungsi menyimpan berbagai data dan instruksi program.")
print("Isi dari RAM dapat diakses secara random atau tidak mengacu pada pengaturan letak data.")
print("Data di dalam RAM bersifat sementara, dengan kata lain data yang tersimpan akan hilang jika komputer dimatikan")
# Out:
# RAM yang merupakan singkatan dari Random Access Memory adalah sebuah perangkat keras komputer yang berfungsi menyimpan berbagai data dan instruksi program.
# Isi dari RAM dapat diakses secara random atau tidak mengacu pada pengaturan letak data.
# Data di dalam RAM bersifat sementara, dengan kata lain data yang tersimpan akan hilang jika komputer dimatikan

# %% [markdown]
# * <h3><font color='orange'>ROM</h2></font>

# %%
Image(url="http://4.bp.blogspot.com/-hEowzlndvYY/VN3X5ilt92I/AAAAAAAAAPs/1EtKYFjDBss/s1600/BIOS.jpg", width=200 , height=200)
# Out:
# <img src="http://4.bp.blogspot.com/-hEowzlndvYY/VN3X5ilt92I/AAAAAAAAAPs/1EtKYFjDBss/s1600/BIOS.jpg" width="200" height="200"/>

# %%
print("ROM adalah singkatan dari ' Read Only Memory ' yaitu suatu perangkat keras pada komputer atau PC yang berupa chip memori")
print("ROM juga disebut sebagai non-volatile chip yang berarti data pada ROM ini tidak mudah menghilang dan tertanam pada chip-nya.")
print("Data yang tersimpan di dalam ROM ini tidak akan hilang meskipun kita mematikan daya pada komputer atau laptop kita.")
# Out:
# ROM adalah singkatan dari ' Read Only Memory ' yaitu suatu perangkat keras pada komputer atau PC yang berupa chip memori
# ROM juga disebut sebagai non-volatile chip yang berarti data pada ROM ini tidak mudah menghilang dan tertanam pada chip-nya.
# Data yang tersimpan di dalam ROM ini tidak akan hilang meskipun kita mematikan daya pada komputer atau laptop kita.

# %% [markdown]
# > ROM biasa digunakan untuk menyimpan firmware

# %% [markdown]
# <h2 align = "left"> <font color='green'> 2.Eksternal Storage </h2> </font>

# %% [markdown]
# * <h3><font color='purple'>CD</h2></font>

# %%
from IPython.display import Image
Image(filename="cd.jpg", width=200 , height=200)

# %%
print(" CD adalah cakram optik digital yang digunakan untuk menyimpan data.")
# Out:
#  CD adalah cakram optik digital yang digunakan untuk menyimpan data.

# %% [markdown]
# * <h3><font color='purple'>USB FLASH DRIVE</h2></font>

# %%
from IPython.display import Image
Image(filename="flash.jpg", width=200 , height=200)

# %%
print ("Flash drive adalah alat penyimpanan portabel berukuran kecil, tidak lebih besar dari ibu jari, yang digunakan untuk menyimpan atau mentransfer file dari satu komputer ke komputer lain.")
# Out:
# Flash drive adalah alat penyimpanan portabel berukuran kecil, tidak lebih besar dari ibu jari, yang digunakan untuk menyimpan atau mentransfer file dari satu komputer ke komputer lain.

# %% [markdown]
# * <h3><font color='purple'>HARD DISK DRIVE</h2></font>

# %%
from IPython.display import Image
Image(filename="hdd.jpg", width=200 , height=200)

# %%
print ("Hard Disk Drive biasa juga disebut Hard disk atau HDD adalah perangkat penyimpanan data yang digunakan untuk menyimpan dan mengambil informasi ")
print("Hard Disk Drive menyimpan data dan mengambil data menggunakan disk (cakram) yang dilapisi dengan bahan magnetik.")
# Out:
# Hard Disk Drive biasa juga disebut Hard disk atau HDD adalah perangkat penyimpanan data yang digunakan untuk menyimpan dan mengambil informasi
# Hard Disk Drive menyimpan data dan mengambil data menggunakan disk (cakram) yang dilapisi dengan bahan magnetik.

# %% [markdown]
# * <h3><font color='purple'>SOLID STATE DRIVE</h2></font>

# %%
from IPython.display import Image
Image(filename="ssd1.jpg", width=250 , height=250)

# %%
print("Solid state drive adalah media penyimpanan data (storage) yang menggunakan solid state memory untuk penyimpanan datanya.")
print("Berbeda dengan hard disk yang menggunakan platter magnetis yang berputar, SSD menggunakan semikonduktor.")
# Out:
# Solid state drive adalah media penyimpanan data (storage) yang menggunakan solid state memory untuk penyimpanan datanya.
# Berbeda dengan hard disk yang menggunakan platter magnetis yang berputar, SSD menggunakan semikonduktor.

# %% [markdown]
# * <h3><font color='purple'>CLOUD STORAGE</h2></font>

# %% [markdown]
# ### Pengertian Cloud Storage

# %%
from IPython.display import Image
Image(filename="cloudstorage.jpg", width=600, height=500)

# %%
print("Cloud storage adalah metode penyimpanan data di sejumlah server yang dikelola pihak penyedia layanan. Koneksi internet dibutuhkan untuk mengakses data yang kamu simpan di server.")
print("Informasi dalam cloud storage disimpan dalam sebuah server yang biasanya dikelola pihak ketiga, seperti perusahaan hosting. Proses penyimpanan dan pengelolaannya berbeda ketika kamu menggunakan perangkat memori fisik, di mana informasi yang kamu simpan hanya terdapat dalam perangkat yang kamu gunakan, serta hanya bisa diakses dari situ.")
# Out:
# Cloud storage adalah metode penyimpanan data di sejumlah server yang dikelola pihak penyedia layanan. Koneksi internet dibutuhkan untuk mengakses data yang kamu simpan di server.
# Informasi dalam cloud storage disimpan dalam sebuah server yang biasanya dikelola pihak ketiga, seperti perusahaan hosting. Proses penyimpanan dan pengelolaannya berbeda ketika kamu menggunakan perangkat memori fisik, di mana informasi yang kamu simpan hanya terdapat dalam perangkat yang kamu gunakan, serta hanya bisa diakses dari situ.

# %%
print("komputasi awan diyakini telah ditemukan oleh Josep Carl Robnett Licklider. CompuServe menawarkan kepada pengguna konsumer sejumlah kecil ruang disk yang dapat digunakan untuk menyimpan file apa pun yang mereka pilih untuk diunggah.")
# Out:
# komputasi awan diyakini telah ditemukan oleh Josep Carl Robnett Licklider. CompuServe menawarkan kepada pengguna konsumer sejumlah kecil ruang disk yang dapat digunakan untuk menyimpan file apa pun yang mereka pilih untuk diunggah.

# %% [markdown]
# ### Keuntungan
# - Perusahaan
# - Organisasi
# - intrinsik untuk arsitektur penyimpanan objek
# - Tugas pemeliharaan penyimpanan
# ### Kekurangan
#     - Serangan dari area permukaan
#     - Stabilitas penyedia
#     - Aksesibilitas
#     - Pengguna dengan persyaratan penyimpanan catatan tertentu
