# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data survey.csv')

# %% [markdown]
# # Info Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                         --------------  -----
#  0   No                                                                                             500 non-null    int64
#  1   Seberapa sering anda menggunakan bahasa pemrograman C?                                         500 non-null    int64
#  2   Seberapa tahukah anda tentang bahasa permograman Java?                                         500 non-null    int64
#  3   Pernahkah anda membuat program menggunakan bahasa pemrograman Python?                          500 non-null    int64
#  4   Seberapa tahukah anda tentang Pemrograman Interface (API)?                                     500 non-null    int64
#  5   Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?                            500 non-null    int64
#  6   Seberapa sering anda menggunakan programming software bajakan?                                 500 non-null    int64
#  7   Seberapa perlunya dokumen manual/tutorial ketika membuat program?                              500 non-null    int64
#  8   Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?     500 non-null    int64
#  9   Seberapa seringkah anda menggunakan Extension saat membuat program?                            500 non-null    int64
#  10  Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?  500 non-null    int64
#  11   Apakah anda sering menggunakan Extension berbayar?                                            500 non-null    int64
#  12   Apakah anda sering menggunakan Auto Indent Extension?                                         500 non-null    int64
# dtypes: int64(13)
# memory usage: 50.9 KB

# %%
df.dtypes
# Out:
# No                                                                                               int64
# Seberapa sering anda menggunakan bahasa pemrograman C?                                           int64
# Seberapa tahukah anda tentang bahasa permograman Java?                                           int64
# Pernahkah anda membuat program menggunakan bahasa pemrograman Python?                            int64
# Seberapa tahukah anda tentang Pemrograman Interface (API)?                                       int64
# Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?                              int64
# Seberapa sering anda menggunakan programming software bajakan?                                   int64
# Seberapa perlunya dokumen manual/tutorial ketika membuat program?                                int64
# Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?       int64
# Seberapa seringkah anda menggunakan Extension saat membuat program?                              int64
# Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?    int64
#  Apakah anda sering menggunakan Extension berbayar?                                              int64
#  Apakah anda sering menggunakan Auto Indent Extension?                                           int64
# dtype: object

# %% [markdown]
# # Data Awal Tabel

# %%
df.head(6)
# Out:
#    No  Seberapa sering anda menggunakan bahasa pemrograman C?  \
# 0   1                                                  3
# 1   2                                                  1
# 2   3                                                  1
# 3   4                                                  4
# 4   5                                                  3
# 5   6                                                  1
#
#    Seberapa tahukah anda tentang bahasa permograman Java?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  2
# 5                                                  2
#
#    Pernahkah anda membuat program menggunakan bahasa pemrograman Python?  \
# 0                                                  2
# 1                                                  2
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  2
#
#    Seberapa tahukah anda tentang Pemrograman Interface (API)?  \
# 0                                                  1
# 1                                                  1
# 2                                                  3
# 3                                                  2
# 4                                                  1
# 5                                                  2
#
#    Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?  \
# 0                                                  1
# 1                                                  1
# 2                                                  2
# 3                                                  2
# 4                                                  1
# 5                                                  4
#
#    Seberapa sering anda menggunakan programming software bajakan?  \
# 0                                                  3
# 1                                                  3
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  2
#
#    Seberapa perlunya dokumen manual/tutorial ketika membuat program?  \
# 0                                                  5
# 1                                                  5
# 2                                                  4
# 3                                                  4
# 4                                                  1
# 5                                                  5
#
#    Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?  \
# 0                                                  1
# 1                                                  1
# 2                                                  4
# 3                                                  1
# 4                                                  1
# 5                                                  4
#
#    Seberapa seringkah anda menggunakan Extension saat membuat program?  \
# 0                                                  1
# 1                                                  1
# 2                                                  3
# 3                                                  1
# 4                                                  1
# 5                                                  3
#
#    Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?  \
# 0                                                  1
# 1                                                  1
# 2                                                  3
# 3                                                  3
# 4                                                  1
# 5                                                  1
#
#     Apakah anda sering menggunakan Extension berbayar?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  1
#
#     Apakah anda sering menggunakan Auto Indent Extension?
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
# 5                                                  1

# %% [markdown]
# # Data Akhir Tabel

# %%
df.tail()
# Out:
#       No  Seberapa sering anda menggunakan bahasa pemrograman C?  \
# 495  496                                                  1
# 496  497                                                  1
# 497  498                                                  3
# 498  499                                                  1
# 499  500                                                  3
#
#      Seberapa tahukah anda tentang bahasa permograman Java?  \
# 495                                                  1
# 496                                                  1
# 497                                                  2
# 498                                                  1
# 499                                                  2
#
#      Pernahkah anda membuat program menggunakan bahasa pemrograman Python?  \
# 495                                                  1
# 496                                                  1
# 497                                                  2
# 498                                                  1
# 499                                                  2
#
#      Seberapa tahukah anda tentang Pemrograman Interface (API)?  \
# 495                                                  2
# 496                                                  1
# 497                                                  2
# 498                                                  1
# 499                                                  2
#
#      Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?  \
# 495                                                  2
# 496                                                  1
# 497                                                  2
# 498                                                  3
# 499                                                  3
#
#      Seberapa sering anda menggunakan programming software bajakan?  \
# 495                                                  2
# 496                                                  3
# 497                                                  4
# 498                                                  3
# 499                                                  3
#
#      Seberapa perlunya dokumen manual/tutorial ketika membuat program?  \
# 495                                                  2
# 496                                                  4
# 497                                                  5
# 498                                                  5
# 499                                                  5
#
#      Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?  \
# 495                                                  1
# 496                                                  1
# 497                                                  2
# 498                                                  1
# 499                                                  1
#
#      Seberapa seringkah anda menggunakan Extension saat membuat program?  \
# 495                                                  1
# 496                                                  1
# 497                                                  1
# 498                                                  1
# 499                                                  1
#
#      Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?  \
# 495                                                  1
# 496                                                  1
# 497                                                  1
# 498                                                  1
# 499                                                  1
#
#       Apakah anda sering menggunakan Extension berbayar?  \
# 495                                                  1
# 496                                                  1
# 497                                                  1
# 498                                                  1
# 499                                                  1
#
#       Apakah anda sering menggunakan Auto Indent Extension?
# 495                                                  1
# 496                                                  1
# 497                                                  1
# 498                                                  1
# 499                                                  1

# %% [markdown]
# # Dimensi Data

# %%
df.shape
# Out:
# (500, 13)

# %% [markdown]
# # Jumlah Feature yang Tersedia

# %%
df.columns
# Out:
# Index(['No', 'Seberapa sering anda menggunakan bahasa pemrograman C?',
#        'Seberapa tahukah anda tentang bahasa permograman Java?',
#        'Pernahkah anda membuat program menggunakan bahasa pemrograman Python?',
#        'Seberapa tahukah anda tentang Pemrograman Interface (API)?',
#        'Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?',
#        'Seberapa sering anda menggunakan programming software bajakan?',
#        'Seberapa perlunya dokumen manual/tutorial ketika membuat program?',
#        'Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?',
#        'Seberapa seringkah anda menggunakan Extension saat membuat program?',
#        'Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?',
#        ' Apakah anda sering menggunakan Extension berbayar?',
#        ' Apakah anda sering menggunakan Auto Indent Extension?'],
#       dtype='object')

# %% [markdown]
# # Gambaran Statistik Setiap Features

# %%
df.describe()
# Out:
#                No  Seberapa sering anda menggunakan bahasa pemrograman C?  \
# count  500.000000                                         500.000000
# mean   250.500000                                           2.324000
# std    144.481833                                           1.205791
# min      1.000000                                           1.000000
# 25%    125.750000                                           1.000000
# 50%    250.500000                                           3.000000
# 75%    375.250000                                           3.000000
# max    500.000000                                           5.000000
#
#        Seberapa tahukah anda tentang bahasa permograman Java?  \
# count                                         500.000000
# mean                                            2.192000
# std                                             1.090649
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Pernahkah anda membuat program menggunakan bahasa pemrograman Python?  \
# count                                         500.000000
# mean                                            1.600000
# std                                             1.022786
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             5.000000
#
#        Seberapa tahukah anda tentang Pemrograman Interface (API)?  \
# count                                         500.000000
# mean                                            2.000000
# std                                             1.051766
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?  \
# count                                         500.000000
# mean                                            2.106000
# std                                             1.158208
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Seberapa sering anda menggunakan programming software bajakan?  \
# count                                         500.000000
# mean                                            2.306000
# std                                             1.292945
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Seberapa perlunya dokumen manual/tutorial ketika membuat program?  \
# count                                         500.000000
# mean                                            3.786000
# std                                             1.266259
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             5.000000
#
#        Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?  \
# count                                         500.000000
# mean                                            2.034000
# std                                             1.350738
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Seberapa seringkah anda menggunakan Extension saat membuat program?  \
# count                                         500.000000
# mean                                            2.038000
# std                                             1.245656
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             3.000000
# max                                             5.000000
#
#        Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?  \
# count                                         500.000000
# mean                                            2.206000
# std                                             1.273895
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             3.000000
# max                                             5.000000
#
#         Apakah anda sering menggunakan Extension berbayar?  \
# count                                         500.000000
# mean                                            1.654000
# std                                             1.033644
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                             5.000000
#
#         Apakah anda sering menggunakan Auto Indent Extension?
# count                                         500.000000
# mean                                            1.680000
# std                                             1.069527
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             3.000000
# max                                             5.000000

# %%
col_to_drop = ['No']
df= df.drop(col_to_drop, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-9ac4a8e159c1> in <module>
#       1 col_to_drop = ['No']
# ----> 2 df= df.drop(col_to_drop, axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['No'] not found in axis"

# %% [markdown]
# # Mean

# %%
print ("mean :")
df.mean()
# Out:
# mean :
# Seberapa sering anda menggunakan bahasa pemrograman C?                                           2.324
# Seberapa tahukah anda tentang bahasa permograman Java?                                           2.192
# Pernahkah anda membuat program menggunakan bahasa pemrograman Python?                            1.600
# Seberapa tahukah anda tentang Pemrograman Interface (API)?                                       2.000
# Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?                              2.106
# Seberapa sering anda menggunakan programming software bajakan?                                   2.306
# Seberapa perlunya dokumen manual/tutorial ketika membuat program?                                3.786
# Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?       2.034
# Seberapa seringkah anda menggunakan Extension saat membuat program?                              2.038
# Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?    2.206
#  Apakah anda sering menggunakan Extension berbayar?                                              1.654
#  Apakah anda sering menggunakan Auto Indent Extension?                                           1.680
# dtype: float64

# %% [markdown]
# # Correlations

# %%
correlations = df.corr(method= 'kendall')

# %%
correlations
# Out:
#                                                     Seberapa sering anda menggunakan bahasa pemrograman C?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           1.000000
# Seberapa tahukah anda tentang bahasa permograma...                                           0.481365
# Pernahkah anda membuat program menggunakan baha...                                           0.322687
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.351777
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.340846
# Seberapa sering anda menggunakan programming so...                                           0.077627
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.123431
# Pernakah anda melakukan trial dan error atau me...                                           0.293891
# Seberapa seringkah anda menggunakan Extension s...                                           0.388235
# Seberapa sering anda mengelola (menginstal,meng...                                           0.391250
#  Apakah anda sering menggunakan Extension berba...                                           0.338975
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.393811
#
#                                                     Seberapa tahukah anda tentang bahasa permograman Java?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.481365
# Seberapa tahukah anda tentang bahasa permograma...                                           1.000000
# Pernahkah anda membuat program menggunakan baha...                                           0.412108
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.514678
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.490715
# Seberapa sering anda menggunakan programming so...                                           0.131050
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.156369
# Pernakah anda melakukan trial dan error atau me...                                           0.324895
# Seberapa seringkah anda menggunakan Extension s...                                           0.454054
# Seberapa sering anda mengelola (menginstal,meng...                                           0.390038
#  Apakah anda sering menggunakan Extension berba...                                           0.335209
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.401794
#
#                                                     Pernahkah anda membuat program menggunakan bahasa pemrograman Python?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.322687
# Seberapa tahukah anda tentang bahasa permograma...                                           0.412108
# Pernahkah anda membuat program menggunakan baha...                                           1.000000
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.449629
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.442907
# Seberapa sering anda menggunakan programming so...                                           0.183894
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.089399
# Pernakah anda melakukan trial dan error atau me...                                           0.408902
# Seberapa seringkah anda menggunakan Extension s...                                           0.443547
# Seberapa sering anda mengelola (menginstal,meng...                                           0.291173
#  Apakah anda sering menggunakan Extension berba...                                           0.322436
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.445185
#
#                                                     Seberapa tahukah anda tentang Pemrograman Interface (API)?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.351777
# Seberapa tahukah anda tentang bahasa permograma...                                           0.514678
# Pernahkah anda membuat program menggunakan baha...                                           0.449629
# Seberapa tahukah anda tentang Pemrograman Inter...                                           1.000000
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.692898
# Seberapa sering anda menggunakan programming so...                                           0.195095
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.115425
# Pernakah anda melakukan trial dan error atau me...                                           0.331256
# Seberapa seringkah anda menggunakan Extension s...                                           0.479022
# Seberapa sering anda mengelola (menginstal,meng...                                           0.373284
#  Apakah anda sering menggunakan Extension berba...                                           0.332309
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.419382
#
#                                                     Seberapa tahukah anda tentang Pemrograman Berorientasi Objek (OOP)?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.340846
# Seberapa tahukah anda tentang bahasa permograma...                                           0.490715
# Pernahkah anda membuat program menggunakan baha...                                           0.442907
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.692898
# Seberapa tahukah anda tentang Pemrograman Beror...                                           1.000000
# Seberapa sering anda menggunakan programming so...                                           0.231925
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.142467
# Pernakah anda melakukan trial dan error atau me...                                           0.359346
# Seberapa seringkah anda menggunakan Extension s...                                           0.490267
# Seberapa sering anda mengelola (menginstal,meng...                                           0.368754
#  Apakah anda sering menggunakan Extension berba...                                           0.292026
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.385657
#
#                                                     Seberapa sering anda menggunakan programming software bajakan?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.077627
# Seberapa tahukah anda tentang bahasa permograma...                                           0.131050
# Pernahkah anda membuat program menggunakan baha...                                           0.183894
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.195095
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.231925
# Seberapa sering anda menggunakan programming so...                                           1.000000
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.129215
# Pernakah anda melakukan trial dan error atau me...                                           0.321082
# Seberapa seringkah anda menggunakan Extension s...                                           0.270969
# Seberapa sering anda mengelola (menginstal,meng...                                           0.214591
#  Apakah anda sering menggunakan Extension berba...                                           0.200994
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.278129
#
#                                                     Seberapa perlunya dokumen manual/tutorial ketika membuat program?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.123431
# Seberapa tahukah anda tentang bahasa permograma...                                           0.156369
# Pernahkah anda membuat program menggunakan baha...                                           0.089399
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.115425
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.142467
# Seberapa sering anda menggunakan programming so...                                           0.129215
# Seberapa perlunya dokumen manual/tutorial ketik...                                           1.000000
# Pernakah anda melakukan trial dan error atau me...                                           0.196409
# Seberapa seringkah anda menggunakan Extension s...                                           0.190381
# Seberapa sering anda mengelola (menginstal,meng...                                           0.173285
#  Apakah anda sering menggunakan Extension berba...                                           0.044772
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.064227
#
#                                                     Pernakah anda melakukan trial dan error atau mengembangkan program yang dibuat orang lain?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.293891
# Seberapa tahukah anda tentang bahasa permograma...                                           0.324895
# Pernahkah anda membuat program menggunakan baha...                                           0.408902
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.331256
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.359346
# Seberapa sering anda menggunakan programming so...                                           0.321082
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.196409
# Pernakah anda melakukan trial dan error atau me...                                           1.000000
# Seberapa seringkah anda menggunakan Extension s...                                           0.503911
# Seberapa sering anda mengelola (menginstal,meng...                                           0.383245
#  Apakah anda sering menggunakan Extension berba...                                           0.377782
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.487561
#
#                                                     Seberapa seringkah anda menggunakan Extension saat membuat program?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.388235
# Seberapa tahukah anda tentang bahasa permograma...                                           0.454054
# Pernahkah anda membuat program menggunakan baha...                                           0.443547
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.479022
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.490267
# Seberapa sering anda menggunakan programming so...                                           0.270969
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.190381
# Pernakah anda melakukan trial dan error atau me...                                           0.503911
# Seberapa seringkah anda menggunakan Extension s...                                           1.000000
# Seberapa sering anda mengelola (menginstal,meng...                                           0.652170
#  Apakah anda sering menggunakan Extension berba...                                           0.462559
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.615666
#
#                                                     Seberapa sering anda mengelola (menginstal,menghapus,menonaktifkan instalasi) Extension anda?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.391250
# Seberapa tahukah anda tentang bahasa permograma...                                           0.390038
# Pernahkah anda membuat program menggunakan baha...                                           0.291173
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.373284
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.368754
# Seberapa sering anda menggunakan programming so...                                           0.214591
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.173285
# Pernakah anda melakukan trial dan error atau me...                                           0.383245
# Seberapa seringkah anda menggunakan Extension s...                                           0.652170
# Seberapa sering anda mengelola (menginstal,meng...                                           1.000000
#  Apakah anda sering menggunakan Extension berba...                                           0.520178
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.535710
#
#                                                      Apakah anda sering menggunakan Extension berbayar?  \
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.338975
# Seberapa tahukah anda tentang bahasa permograma...                                           0.335209
# Pernahkah anda membuat program menggunakan baha...                                           0.322436
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.332309
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.292026
# Seberapa sering anda menggunakan programming so...                                           0.200994
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.044772
# Pernakah anda melakukan trial dan error atau me...                                           0.377782
# Seberapa seringkah anda menggunakan Extension s...                                           0.462559
# Seberapa sering anda mengelola (menginstal,meng...                                           0.520178
#  Apakah anda sering menggunakan Extension berba...                                           1.000000
#  Apakah anda sering menggunakan Auto Indent Ext...                                           0.623726
#
#                                                      Apakah anda sering menggunakan Auto Indent Extension?
# Seberapa sering anda menggunakan bahasa pemrogr...                                           0.393811
# Seberapa tahukah anda tentang bahasa permograma...                                           0.401794
# Pernahkah anda membuat program menggunakan baha...                                           0.445185
# Seberapa tahukah anda tentang Pemrograman Inter...                                           0.419382
# Seberapa tahukah anda tentang Pemrograman Beror...                                           0.385657
# Seberapa sering anda menggunakan programming so...                                           0.278129
# Seberapa perlunya dokumen manual/tutorial ketik...                                           0.064227
# Pernakah anda melakukan trial dan error atau me...                                           0.487561
# Seberapa seringkah anda menggunakan Extension s...                                           0.615666
# Seberapa sering anda mengelola (menginstal,meng...                                           0.535710
#  Apakah anda sering menggunakan Extension berba...                                           0.623726
#  Apakah anda sering menggunakan Auto Indent Ext...                                           1.000000

# %% [markdown]
# # Correlation Map

# %%
f, ax = plt.subplots(figsize=(25,10))
sns.heatmap(correlations, annot=True, fmt='.3f')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
