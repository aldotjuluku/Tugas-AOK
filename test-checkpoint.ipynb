# %% [markdown]
# # STORAGE
# #### Kelompok 7
# -asdaw

# %%
Image(url="data:image/jpeg;base64,...")
# Out:
# <img src="data:image/jpeg;base64,..."/>

# %% [markdown]
# ## PENGERTIAN STORAGE

# %%
from IPython.display import Image
Image(filename="images1.jpg", width=400, height=600)
